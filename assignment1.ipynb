# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Sum =", a + b)
print("Difference =", a - b)
print("Product =", a * b)
print("Quotient =", a / b)
# Out:
# Enter first number:  58
# Enter second number:  98
# Sum = 156.0
# Difference = -40.0
# Product = 5684.0
# Quotient = 0.5918367346938775

# %%
l = float(input("Enter length: "))
w = float(input("Enter width: "))
a = l * w
p = 2 * (l+ w)

print("Area =", a)
print("Perimeter =", p)
# Out:
# Enter length:  45
# Enter width:  75
# Area = 3375.0
# Perimeter = 240.0

# %%
num = int(input("Enter a number: "))
print("Square =", num ** 2)
print("Cube =", num ** 3)
# Out:
# Enter a number:  5
# Square = 25
# Cube = 125

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("Quotient =", a // b)
print("Remainder =", a % b)
# Out:
# Enter first number:  65
# Enter second number:  5
# Quotient = 13
# Remainder = 0

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number "))
print(a == b)
# Out:
# Enter first number:  54
# Enter second number:  8
# False

# %%
age = int(input("Enter age "))
print(age >= 18)
# Out:
# Enter age:  45
# True

# %%
marks = int(input("Enter marks"))
print(marks < 40)
# Out:
# Enter marks:  65
# False

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a > b and a > c:
    print("Largest =", a)
elif b > a and b > c:
    print("Largest =", b)
else:
    print("Largest =", c)
# Out:
# Enter first number:  85
# Enter second number:  55
# Enter third number:  7
# Largest = 85

# %%
age = int(input("Enter age "))
print(age >= 18 and age <= 60)
# Out:
# Enter age:  56
# True

# %%
theory = int(input("Enter theory marks:"))
practical = int(input("Enter practical marks"))
print(theory >= 40 and practical >= 40)
# Out:
# Enter theory marks:  65
# Enter practical marks:  23
# False

# %%
num = int(input("Enter a number "))
print(num > 10 and num < 100)
# Out:
# Enter a number:  77
# True

# %%
username = input("Enter username ")
password = input("Enter password")
print(username == "admin" and password == "1234")
# Out:
# Enter username  56
# Enter password 24
# False

# %%
member = input("Are you a member ")
purchase = float(input("Enter purchase amount "))
if member == "yes" or purchase > 5000:
    print("Eligible for discount")
else:
    print("Not eligible for discount")
# Out:
# Are you a member  56
# Enter purchase amount  23
# Not eligible for discount

# %%
word = input("Enter a word")
char = input("Enter a character ")
print(char in word)
# Out:
# Enter a word 56
# Enter a character  22
# False

# %%
numbers = [10, 20, 30, 40, 50]
num = int(input("Enter a number: "))
print(num in numbers)
# Out:
# Enter a number:  36
# False

# %%
absent_students = ["Rahul", "Amit", "Riya", "Neha"]
name = input("Enter student name: ")
print(name not in absent_students)
# Out:
# Enter student name:  89
# True

# %%
sentence = input("Enter a sentence")
print("Python" in sentence)
# Out:
# Enter a sentence 85
# False

# %%
colours = ["red", "blue", "green", "yellow"]
colour = input("Enter a colour: ")
print(colour in colours)
# Out:
# Enter a colour:  green
# True

# %%
n = 10
n += 5
print(n)
# Out:
# 15

# %%
n = 29
n -= 8
print(n)
# Out:
# 21

# %%
n = 3
n *= 4
print(n)
# Out:
# 12

# %%
num = 100
num /= 5
print(num)
# Out:
# 20.0

# %%
balance = 10000
deposit = 2500
balance += deposit
print("Bank Balance =", balance)
# Out:
# Bank Balance = 12500
